# %%
#Task 1
from package.math_utils import *
print(add(4,5))
print(substract(10,2))
print(square(5))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Task 1
# ----> 2 from package.math_utils import *
#       3 print(add(4,5))
#       4 print(substract(10,2))
#
# ModuleNotFoundError: No module named 'package'

# %%
# Task 2
from package.string_utils import *
text = 'Hi hello this is teja how are you'
print(capitalize_words(text))
print(revesre_string(text))
print(word_count(text))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Task 2
# ----> 2 from package.string_utils import *
#       3 text = 'Hi hello this is teja how are you'
#       4 print(capitalize_words(text))
#
# ModuleNotFoundError: No module named 'package'

# %%
# Task 3

import sys
sys.path.insert(0, '..')
from package.shop_package.billing import *
print(apply_tax(500))
print(calculate_total([100,200,300]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       3 import sys
#       4 sys.path.insert(0, '..')
# ----> 5 from package.shop_package.billing import *
#       6 print(apply_tax(500))
#       7 print(calculate_total([100,200,300]))
#
# ModuleNotFoundError: No module named 'package.shop_package'

# %%
# Task 4:
import package.shop_package.discount as disc
from package.shop_package.billing import calculate_total 
print(disc.apply_discount(1000,10))
print(calculate_total([100,200,300,500]))
print(apply_tax(2500))
print(disc.flat_discount(500))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Task 4:
# ----> 2 import package.shop_package.discount as disc
#       3 from package.shop_package.billing import calculate_total
#       4 print(disc.apply_discount(1000,10))
#
# ModuleNotFoundError: No module named 'package.shop_package'
